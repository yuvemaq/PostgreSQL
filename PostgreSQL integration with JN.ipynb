# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Install-libraries" data-toc-modified-id="Install-libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Install libraries</a></span></li><li><span><a href="#Connecting-libraries-to-database" data-toc-modified-id="Connecting-libraries-to-database-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Connecting libraries to database</a></span></li><li><span><a href="#Complete-SQL-Bootcamp-2022:-Go-from-Zero-to-Hero---Practice-Querying" data-toc-modified-id="Complete-SQL-Bootcamp-2022:-Go-from-Zero-to-Hero---Practice-Querying-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Complete SQL Bootcamp 2022: Go from Zero to Hero - Practice Querying</a></span><ul class="toc-item"><li><span><a href="#Beginner" data-toc-modified-id="Beginner-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Beginner</a></span></li><li><span><a href="#Intermediate" data-toc-modified-id="Intermediate-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Intermediate</a></span></li></ul></li></ul></div>

# %% [markdown]
# This notebook serves as a practice for integrating PostgreSQL with Jupyter Notebook. Main inspiration for this notebook comes from [Medium.com](https://medium.com/analytics-vidhya/postgresql-integration-with-jupyter-notebook-deb97579a38d).
#
# Since I'm rather new to these DBAPIs (DataBase Application Programming Interface), I find it helpful to give a quick info.
#
# - **ipython-sql**: enables use of SQL functions that hold % and %%, which let's you write SQL queries on Jupyter notebook.
#
# - **sqlalchemy**: Object-relational-mapper for Python; store SQL queries into pandas dataframe.

# %% [markdown]
# # Install libraries

# %%
# !pip install ipython-sql
# !pip install sqlalchemy
# Out:
# ...
#   Using cached sqlparse-0.4.2-py3-none-any.whl (42 kB)
# ...
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13699 sha256=8ce79f26de02ad4687f98aad36b231587318fef2de61beacdb0f4da775115679
#   Stored in directory: c:\users\yuvem\appdata\local\pip\cache\wheels\48\6d\77\9517cb933af254f51a446f1a5ec9c2be3e45f17384940bce68
# Successfully built prettytable
# ...

# %%
# !pip install psycopg2

# %%
#Load ipython-sql
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
from sqlalchemy import create_engine

# %% [markdown]
# # Connecting libraries to database

# %%
# Format
#%sql dialect+driver://username:password@host:port/database
# Connect ipython-sql to DB
# %sql postgresql://postgres:h1dar1@M1G1@localhost/dvdrental

# %%
# Connect sqlalchemy to DB
engine = create_engine('postgresql://postgres:h1dar1@M1G1@localhost/dvdrental')

# %% [markdown]
# Okay, let's see how lucky I am today.

# %% [markdown]
# # Complete SQL Bootcamp 2022: Go from Zero to Hero - Practice Querying

# %% [markdown]
# ## Beginner

# %% [markdown]
# Before creating this notebook, I was doing some querying through pgAdmin and then figured it would be a great idea to visualize it on Jupyter.
#
# 1. Use Select statement to get first and last names of every customer and their email address.

# %%
# %%sql
# SELECT first_name, last_name, email FROM customer;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 599 rows affected.
# [('Jared', 'Ely', 'jared.ely@sakilacustomer.org'),
#  ('Mary', 'Smith', 'mary.smith@sakilacustomer.org'),
#  ('Patricia', 'Johnson', 'patricia.johnson@sakilacustomer.org'),
#  ('Linda', 'Williams', 'linda.williams@sakilacustomer.org'),
#  ('Barbara', 'Jones', 'barbara.jones@sakilacustomer.org'),
#  ('Elizabeth', 'Brown', 'elizabeth.brown@sakilacustomer.org'),
#  ('Jennifer', 'Davis', 'jennifer.davis@sakilacustomer.org'),
#  ('Maria', 'Miller', 'maria.miller@sakilacustomer.org'),
#  ('Susan', 'Wilson', 'susan.wilson@sakilacustomer.org'),
#  ('Margaret', 'Moore', 'margaret.moore@sakilacustomer.org'),
#  ('Dorothy', 'Taylor', 'dorothy.taylor@sakilacustomer.org'),
#  ('Lisa', 'Anderson', 'lisa.anderson@sakilacustomer.org'),
#  ('Nancy', 'Thomas', 'nancy.thomas@sakilacustomer.org'),
#  ('Karen', 'Jackson', 'karen.jackson@sakilacustomer.org'),
#  ('Betty', 'White', 'betty.white@sakilacustomer.org'),
# ...

# %% [markdown]
# 2. An Australian visitor is not too familiar with MPAA movie ratings. What ratings do we have available in our data?

# %%
# %%sql
# SELECT DISTINCT rating FROM film;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 5 rows affected.
# [('G',), ('PG-13',), ('NC-17',), ('PG',), ('R',)]

# %% [markdown]
# 3. *self-made question* Does offering more special features increase replacement cost?

# %%
# %%sql
# SELECT DISTINCT(replacement_cost), special_features FROM film
# ORDER BY replacement_cost DESC;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 297 rows affected.
# [(Decimal('29.99'), ['Trailers', 'Deleted Scenes']),
#  (Decimal('29.99'), ['Commentaries', 'Deleted Scenes']),
#  (Decimal('29.99'), ['Trailers', 'Commentaries', 'Deleted Scenes']),
#  (Decimal('29.99'), ['Trailers', 'Commentaries', 'Behind the Scenes']),
#  (Decimal('29.99'), ['Trailers', 'Commentaries']),
#  (Decimal('29.99'), ['Trailers', 'Behind the Scenes']),
#  (Decimal('29.99'), ['Commentaries', 'Deleted Scenes', 'Behind the Scenes']),
#  (Decimal('29.99'), ['Trailers', 'Commentaries', 'Deleted Scenes', 'Behind the Scenes']),
#  (Decimal('29.99'), ['Behind the Scenes']),
#  (Decimal('29.99'), ['Commentaries']),
#  (Decimal('29.99'), ['Deleted Scenes']),
#  (Decimal('29.99'), ['Trailers']),
#  (Decimal('29.99'), ['Deleted Scenes', 'Behind the Scenes']),
#  (Decimal('29.99'), ['Commentaries', 'Behind the Scenes']),
#  (Decimal('28.99'), ['Trailers']),
# ...

# %%
# %%sql
# SELECT DISTINCT(special_features) FROM film;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 15 rows affected.
# [(['Trailers', 'Commentaries', 'Deleted Scenes'],),
#  (['Trailers', 'Deleted Scenes'],),
#  (['Trailers', 'Commentaries', 'Behind the Scenes'],),
#  (['Deleted Scenes'],),
#  (['Commentaries'],),
#  (['Trailers', 'Commentaries', 'Deleted Scenes', 'Behind the Scenes'],),
#  (['Trailers', 'Behind the Scenes'],),
#  (['Commentaries', 'Behind the Scenes'],),
#  (['Behind the Scenes'],),
#  (['Trailers', 'Commentaries'],),
#  (['Commentaries', 'Deleted Scenes'],),
#  (['Trailers'],),
#  (['Commentaries', 'Deleted Scenes', 'Behind the Scenes'],),
#  (['Trailers', 'Deleted Scenes', 'Behind the Scenes'],),
#  (['Deleted Scenes', 'Behind the Scenes'],)]

# %% [markdown]
# Answer: No

# %% [markdown]
# ## Intermediate

# %% [markdown]
# 3. We are launching a platinum service for the loyalest of the loyal customers. We will assign platinum status to customers that have had 40 or more transaction payments. What customer_ids are eligible for platinum status?

# %%
# %%sql
# SELECT customer_id, COUNT(amount) FROM payment
# GROUP BY customer_id
# HAVING COUNT(amount) >=40;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 3 rows affected.
# [(144, 40), (526, 42), (148, 45)]

# %% [markdown]
# 4. What are the customer ids of customers who have spent more than $100$ in payment transactions with our staff_id member 2?

# %%
# %%sql
# SELECT customer_id, SUM(amount) FROM payment
# WHERE staff_id = 2
# GROUP BY customer_id
# HAVING SUM(amount) > 100;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 5 rows affected.
# [(187, Decimal('110.81')),
#  (522, Decimal('102.80')),
#  (526, Decimal('101.78')),
#  (211, Decimal('108.77')),
#  (148, Decimal('110.78'))]
